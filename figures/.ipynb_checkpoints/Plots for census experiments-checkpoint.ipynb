# %% [markdown]
# Python code to generate the plots from the matlab experiments.

# %%
import scipy.io as spio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mat_identity = spio.loadmat('../scripts/census_identity.mat', squeeze_me=True)
mat_orth = spio.loadmat('../scripts/census_orth.mat', squeeze_me=True)
mat_spc3 = spio.loadmat('../scripts/census_condition_spc3.mat', squeeze_me=True)
mat_uniform = spio.loadmat('../scripts/census_uniform_sampling.mat', squeeze_me=True)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.plot( mat_identity['block_sizes'], mat_identity['error'], label = 'Identity')
ax.plot( mat_orth['block_sizes'], mat_orth['error'], label = 'Orth')
ax.plot( mat_spc3['block_sizes'], mat_spc3['error'], label = 'SPC3')
ax.plot( mat_uniform['block_sizes'], mat_uniform['error'], label = 'Sample')
ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('Error: 1 - f_approx/f_exact', fontsize=18)
ax.set_xlabel('Block size (specified)', fontsize=18)
ax.set_title("Error vs Block Size")
ax.legend(loc=0, frameon=False)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.plot( mat_identity['storage'], mat_identity['error'], label = 'Identity')
ax.plot( mat_orth['storage'], mat_orth['error'], label = 'Orth')
ax.plot( mat_spc3['storage'], mat_spc3['error'], label = 'SPC3')
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylabel('Error: 1 - f_approx/f_exact', fontsize=18)
ax.set_xlabel('Rows stored', fontsize=18)
ax.set_title("Error vs Rows stored")
ax.legend(loc=0, frameon=False)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.plot( mat_identity['block_sizes'], mat_identity['storage'], label = 'Identity')
ax.plot( mat_orth['block_sizes'], mat_orth['storage'], label = 'Orth')
ax.plot( mat_spc3['block_sizes'], mat_spc3['storage'], label = 'SPC3')
#ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('Rows Stored', fontsize=18)
ax.set_xlabel('Block Size', fontsize=18)
ax.set_title("Rows stored vs Block Size")
ax.legend(loc=0, frameon=False)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.plot( mat_identity['block_sizes'], mat_identity['approx_regression_time'], label = 'Identity')
ax.plot( mat_orth['block_sizes'], mat_orth['approx_regression_time'], label = 'Orth')
ax.plot( mat_spc3['block_sizes'], mat_spc3['approx_regression_time'], label = 'SPC3')
#ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('Time to solve regression', fontsize=18)
ax.set_xlabel('Block Size', fontsize=18)
ax.set_title("Time to solve regression vs Block Size")
ax.legend(loc=0, frameon=False)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.plot( mat_identity['block_sizes'], mat_identity['total_time'], label = 'Identity')
ax.plot( mat_orth['block_sizes'], mat_orth['total_time'], label = 'Orth')
ax.plot( mat_spc3['block_sizes'], mat_spc3['total_time'], label = 'SPC3')
ax.plot( mat_spc3['block_sizes'], mat_spc3['full_regression_time'], label = 'SPC3')
ax.set_yscale('log')
#ax.set_xscale('log')
ax.set_ylabel('Total Time', fontsize=18)
ax.set_xlabel('Block Size', fontsize=18)
ax.set_title("Total Time  vs Block Size")
ax.legend(loc=0, frameon=False)

# %%
mat_orth['total_time'].shape
# Out:
# (10,)
